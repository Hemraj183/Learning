# %% [markdown]
# # 🚀 Interactive Mode Available!
#
# Typical static notebooks are boring. We have a dedicated interactive module for this week.
#
# [👉 **Click here to open the Interactive Visualization**](../../interactive_platform/modules/week12_capstone/interactive.html)
#
# *(Note: Open this link in a new tab to keep the notebook running)*

# %% [markdown]
# # Week12 Capstone
#
# ## Introduction
# Welcome to the lab for **Week12 Capstone**. In this session, we will dive deep into the implementation details.
#
# ## Goals
# 1. Understand the core theory.
# 2. Implement the key class in `project.py`.
# 3. Run experiments to verify behavior.

# %%
import torch
import torch.nn as nn
import sys
import os

# Auto-reload modules for quick debugging
# %load_ext autoreload
# %autoreload 2

print(f'Ready to master {week_name}!')

# %% [markdown]
# ## 1. Project Implementation
#
# We have implemented the core logic in `project.py`. Let's import it and test it out.

# %%
from project import *

# Inspect the class/function signature
print('Project module loaded successfully.')

# %% [markdown]
# ## 2. Experimentation
#
# Now, let's run a small demo.

# %%
# Run the main block from project.py if available
# !python project.py

# %% [markdown]
# ## 3. Exercises
#
# Open `exercises.py` to see your challenge for this week!

# %%
from exercises import *
# Run the exercise function here
